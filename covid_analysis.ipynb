# %% [markdown]
# <a href="https://colab.research.google.com/github/TanishaKundalwal/Hack-A-Tone/blob/main/covid_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {'cases': [100, 200, 300], 'deaths': [5, 10, 15]}
df = pd.DataFrame(data)
print(df)
df.plot(x='cases', y='deaths', kind='line')
# Out:
#    cases  deaths
# 0    100       5
# 1    200      10
# 2    300      15
# <Axes: xlabel='cases'>
